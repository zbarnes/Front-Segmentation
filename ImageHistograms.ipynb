# %% [markdown]
# # Import Needed Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline
from skimage import io
plt.rcParams['figure.figsize'] = [20, 20]

# %% [markdown]
# ### Extra Imports

# %%
import skimage.segmentation as seg
import skimage.filters as filters
import skimage.draw as draw
import skimage.color as color

# %% [markdown]
# ## Load Image

# %%
img = plt.imread('Glacier.TIF')

# %% [markdown]
# ## Plot Image

# %%
plt.imshow(img) 
# Why is it green? ¯\_(ツ)_/¯

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (8751, 8061)

# %%
img_pil = Image.fromarray(np.uint8(img))
img_pil = ImageOps.equalize(img_pil)

# %%
#plt.imshow(img_pil)

# %%
#plt.hist(img)

# %% [markdown]
# ### Inspect Histogram of Image

# %%
plt.hist(img.ravel())
# Out:
# (array([38461785.,   296176.,   270179.,   673499.,  1883630.,  3363781.,
#         11517640.,  9398793.,  4528932.,   147396.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Define Function for Plotting

# %%
def image_show(image, nrows=1, ncols=1, cmap='gray'):
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, 14))
    ax.imshow(image, cmap='gray')
    ax.axis('off')
    return fig, ax

# %%
image_show(img)
# Out:
# (<matplotlib.figure.Figure at 0x108626940>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10864c208>)

# %%
image_gray = color.rgb2gray(img) 
image_show(image_gray);

# %%
plt.hist(img.ravel())
# Out:
# (array([38461785.,   296176.,   270179.,   673499.,  1883630.,  3363781.,
#         11517640.,  9398793.,  4528932.,   147396.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)
