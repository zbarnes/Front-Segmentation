# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage import feature, io
plt.rcParams['figure.figsize'] = [10,10]

# read image
im = io.imread('cropped_image.jpg')

# Compute the Canny filter for multiple values of sigma
#edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=2)
edges3 = feature.canny(im, sigma=3)
edges4 = feature.canny(im, sigma=4)

# display results
fig, (ax1, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=4, figsize=(30, 30),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('Original image', fontsize=20)

#ax2.imshow(edges1, cmap=plt.cm.gray)
#ax2.axis('off')
#ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=2$', fontsize=20)

ax4.imshow(edges3, cmap=plt.cm.gray)
ax4.axis('off')
ax4.set_title('Canny filter, $\sigma=3$', fontsize=20)

ax5.imshow(edges4, cmap=plt.cm.gray)
ax5.axis('off')
ax5.set_title('Canny filter, $\sigma=4$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
# read image
im2 = io.imread('Glacier.TIF')

# Compute the Canny filter for multiple values of sigma
edg1 = feature.canny(im2)
edg2 = feature.canny(im2, sigma=2)
edg3 = feature.canny(im2, sigma=3)
edg4 = feature.canny(im2, sigma=4)

# display results
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(30, 30),
                                    sharex=True, sharey=True)

ax1.imshow(im2, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('Original image', fontsize=20)

ax2.imshow(edg1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edg2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=2$', fontsize=20)

ax4.imshow(edg3, cmap=plt.cm.gray)
ax4.axis('off')
ax4.set_title('Canny filter, $\sigma=3$', fontsize=20)

ax5.imshow(edg4, cmap=plt.cm.gray)
ax5.axis('off')
ax5.set_title('Canny filter, $\sigma=4$', fontsize=20)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Documentation
#
# $\textit{https://scikit-image.org/docs/dev/api/skimage.feature.html?highlight=feature#skimage.feature.canny}$

# %%
io.imshow(edges2, cmap='gray')

# %%
io.imshow(edges3, cmap='gray')

# %%
io.imshow(edges4, cmap='gray')
